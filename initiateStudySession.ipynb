# %% [markdown]
# # Initiate Study Session

# %% [markdown]
# #### This code simulates a user selecting a deck to study. These are the steps needed to prime the deck for today's study.
#
# - Determine how many cards are due for review
# - Determine how many learning cards are due for study
# - Determine how many new cards to add to Leitner Box

# %%
import pandas as pd
import sqlite3
from datetime import datetime

# %%
# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect('flashcardsTable.db')

# Create a cursor object to execute SQL commands
cursor = conn.cursor()

# %% [markdown]
# ## Load Entire Deck into Panda df and Calculate Due Field

# %%
# Query the entire table and store it into a pandas DataFrame
df = pd.read_sql_query("SELECT * FROM flashcardsTable", conn)
# Close the connection to the database
conn.close()
df.head(5)
# Out:
#    id                                             native  \
# 0   1  The reason for which I couldn't attend the mee...
# 1   2   A few minutes ago, I received an important call.
# 2   3         A new problem has appeared in the project.
# 3   4  After finishing the exams, I decided to unleas...
# 4   5     After he goes to another office, we will meet.
#
#                                               target          lastStudied  \
# 0  La razón por la cual no pude asistir a la reun...  09/25/2024 01:00:00
# 1  Hace unos minutos, recibí una llamada importante.  09/25/2024 01:00:00
# 2     Ha aparecido un nuevo problema en el proyecto.  09/25/2024 01:00:00
# 3  Después de terminar los exámenes, decidí dar r...  09/25/2024 01:00:00
# 4  Después de que vaya a otra oficina, nos reunir...  09/25/2024 01:00:00
#
#    interval cardstate
# 0         5    UNSEEN
# 1         5    UNSEEN
# 2         5    UNSEEN
# 3         5    UNSEEN
# 4         5    UNSEEN

# %%
# Convert the 'datetime_text' column to datetime type
df['lastdate'] = pd.to_datetime(df['lastStudied'])
# Add a new column that adds the 'minutes' to the 'datetime' column
df['due_datetime'] = df['lastdate'] + pd.to_timedelta(df['interval'], unit='m')
#create new columns of of last studied and due dates, ignoring the hours, minutes, and seconds
df['lastdate_calendar'] = df['lastdate'].dt.date
df['duedate_calendar'] = df['due_datetime'].dt.date
df['weight'] = 0

# %%
df.head(5)
# Out:
#    id                                             native  \
# 0   1  The reason for which I couldn't attend the mee...
# 1   2   A few minutes ago, I received an important call.
# 2   3         A new problem has appeared in the project.
# 3   4  After finishing the exams, I decided to unleas...
# 4   5     After he goes to another office, we will meet.
#
#                                               target          lastStudied  \
# 0  La razón por la cual no pude asistir a la reun...  09/25/2024 01:00:00
# 1  Hace unos minutos, recibí una llamada importante.  09/25/2024 01:00:00
# 2     Ha aparecido un nuevo problema en el proyecto.  09/25/2024 01:00:00
# 3  Después de terminar los exámenes, decidí dar r...  09/25/2024 01:00:00
# 4  Después de que vaya a otra oficina, nos reunir...  09/25/2024 01:00:00
#
#    interval cardstate            lastdate        due_datetime  \
# 0         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 1         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 2         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 3         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 4         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
#
#   lastdate_calendar duedate_calendar  weight
# 0        2024-09-25       2024-09-25       0
# 1        2024-09-25       2024-09-25       0
# 2        2024-09-25       2024-09-25       0
# 3        2024-09-25       2024-09-25       0
# 4        2024-09-25       2024-09-25       0

# %% [markdown]
# ## Determine number of cards due for review
#
# These are cards that have been graduated from the learning phase and have also passed their interval.
#
# REMOVE THIS. AND FORGET ABOUT CARDSTATE GRADUATED. The only states we need are UNSEEN, NEW, and SEEN

# %%
# reviewCards = df[(df['cardstate'] == 'GRADUATED') & (df['duedate_calendar'] <= df['lastdate_calendar'])]
# print(len(reviewCards))

# %% [markdown]
# ## Add NEW Cards to a total of 20

# %%
# Step 1: Count how many 'NEW' records there are
new_count = (df['cardstate'] == 'NEW').sum()
print(new_count)
# Out:
# 20

# %%
# Step 2: If there are fewer than 20 'NEW' records, update some 'UNSEEN' records to 'NEW'
if new_count < 20:
    # Calculate how many 'UNSEEN' need to be converted to 'NEW'
    unseen_to_new = 20 - new_count
    
    # Find the indices of the first 'UNSEEN' records
    unseen_indices = df[df['cardstate'] == 'UNSEEN'].index[:unseen_to_new]
    
    # Update those 'UNSEEN' records to 'NEW'
    df.loc[unseen_indices, 'cardstate'] = 'NEW'

# %% [markdown]
# # We should now have exaclty 20 NEW cards. If DB has just been reset, it will be the top 20

# %%
df.head(30)
# Out:
#     id                                             native  \
# 0    1  The reason for which I couldn't attend the mee...
# 1    2   A few minutes ago, I received an important call.
# 2    3         A new problem has appeared in the project.
# 3    4  After finishing the exams, I decided to unleas...
# 4    5     After he goes to another office, we will meet.
# 5    6  After overcoming his fears, he no longer cared...
# 6    7       After playing, the son's mom will clean Max.
# 7    8  After so many issues, I want to get rid of thi...
# 8    9    After so much practice, I know it by heart now.
# 9   10  After the explanation, it's clear to me that w...
# 10  11        After the sale, only a few units were left.
# 11  12  After trying it several times, he realized it ...
# 12  13  All the students sang in unison during the sch...
# 13  14  Already in the early morning, we decided to go...
# 14  15  Although in the background, his contribution w...
# 15  16  Although we were already tired, we decided to ...
# 16  17  Apparently, he won't make it to the meeting on...
# 17  18  Are you going to quit? No way, I'm not even co...
# 18  19  As an artist, it's important to make oneself k...
# 19  20       As far as I know, the project is going well.
# 20  21       As for the project, there are some concerns.
# 21  22  As I was saying before, the situation is compl...
# 22  23  As part of my routine, I wake up at six every ...
# 23  24  As the day progressed, the heat became more in...
# 24  25  As the holidays approached, excitement grew in...
# 25  26  At first, he didn't take the challenge seriously.
# 26  27  At the conference, they also talked about adva...
# 27  28  At the party, there were no shortage of fun mo...
# 28  29  Before answering, he thinks about it for a min...
# 29  30    Before going out, make sure to apply sunscreen.
#
#                                                target          lastStudied  \
# 0   La razón por la cual no pude asistir a la reun...  09/25/2024 01:00:00
# 1   Hace unos minutos, recibí una llamada importante.  09/25/2024 01:00:00
# 2      Ha aparecido un nuevo problema en el proyecto.  09/25/2024 01:00:00
# 3   Después de terminar los exámenes, decidí dar r...  09/25/2024 01:00:00
# 4   Después de que vaya a otra oficina, nos reunir...  09/25/2024 01:00:00
# 5   Después de superar sus miedos, ya no le import...  09/25/2024 01:00:00
# 6   Después de jugar, la mamá del hijo limpiará a ...  09/25/2024 01:00:00
# 7   Después de tantos problemas, quiero quitarme y...  09/25/2024 01:00:00
# 8   Después de tanto practicar, ahora lo sé de mem...  09/25/2024 01:00:00
# 9   Después de la explicación, me queda claro que ...  09/25/2024 01:00:00
# 10  Después de la venta, solo quedaban algunas uni...  09/25/2024 01:00:00
# 11  Luego de intentarlo varias veces, se dio cuent...  09/25/2024 01:00:00
# 12  Todos los estudiantes cantaron al unísono dura...  09/25/2024 01:00:00
# 13           Ya de madrugada, decidimos irnos a casa.  09/25/2024 01:00:00
# 14  Aunque estaba en segundo plano, su contribució...  09/25/2024 01:00:00
# 15  Aunque ya estábamos cansados, decidimos camina...  09/25/2024 01:00:00
# 16   Al parecer, no llegará a tiempo para la reunión.  09/25/2024 01:00:00
# 17  ¿Vas a renunciar? ¡Qué va, ni siquiera lo esto...  09/25/2024 01:00:00
# 18  Como artista, es importante darse a conocer en...  09/25/2024 01:00:00
# 19               Hasta donde sé, el proyecto va bien.  09/25/2024 01:00:00
# 20  En cuanto al proyecto, hay algunas preocupacio...  09/25/2024 01:00:00
# 21  Como te comentaba antes, la situación es compl...  09/25/2024 01:00:00
# 22  Como parte de mi rutina, me levanto a las seis...  09/25/2024 01:00:00
# 23  Conforme avanzaba el día, el calor se volvía m...  09/25/2024 01:00:00
# 24  Conforme se acercaban las vacaciones, la emoci...  09/25/2024 01:00:00
# 25  Al principio, no se había tomado en serio el d...  09/25/2024 01:00:00
# 26  En la conferencia, se hablaba también de los a...  09/25/2024 01:00:00
# 27  En la fiesta, no faltaron los momentos diverti...  09/25/2024 01:00:00
# 28  Antes de responder, él lo piensa durante un mi...  09/25/2024 01:00:00
# 29  Antes de salir, asegúrate de aplicar bloqueado...  09/25/2024 01:00:00
#
#     interval cardstate            lastdate        due_datetime  \
# 0          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 1          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 2          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 3          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 4          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 5          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 6          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 7          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 8          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 9          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 10         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 11         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 12         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 13         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 14         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 15         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 16         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 17         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 18         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 19         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 20         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 21         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 22         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 23         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 24         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 25         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 26         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 27         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 28         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 29         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
#
#    lastdate_calendar duedate_calendar  weight
# 0         2024-09-25       2024-09-25       0
# 1         2024-09-25       2024-09-25       0
# 2         2024-09-25       2024-09-25       0
# 3         2024-09-25       2024-09-25       0
# 4         2024-09-25       2024-09-25       0
# 5         2024-09-25       2024-09-25       0
# 6         2024-09-25       2024-09-25       0
# 7         2024-09-25       2024-09-25       0
# 8         2024-09-25       2024-09-25       0
# 9         2024-09-25       2024-09-25       0
# 10        2024-09-25       2024-09-25       0
# 11        2024-09-25       2024-09-25       0
# 12        2024-09-25       2024-09-25       0
# 13        2024-09-25       2024-09-25       0
# 14        2024-09-25       2024-09-25       0
# 15        2024-09-25       2024-09-25       0
# 16        2024-09-25       2024-09-25       0
# 17        2024-09-25       2024-09-25       0
# 18        2024-09-25       2024-09-25       0
# 19        2024-09-25       2024-09-25       0
# 20        2024-09-25       2024-09-25       0
# 21        2024-09-25       2024-09-25       0
# 22        2024-09-25       2024-09-25       0
# 23        2024-09-25       2024-09-25       0
# 24        2024-09-25       2024-09-25       0
# 25        2024-09-25       2024-09-25       0
# 26        2024-09-25       2024-09-25       0
# 27        2024-09-25       2024-09-25       0
# 28        2024-09-25       2024-09-25       0
# 29        2024-09-25       2024-09-25       0

# %% [markdown]
# # Deck is now ready for study
#
# Due dates and times have been calculated, new cards have been added to the Leitner Box, and we are ready to study. The logic of which cards we study in this session is simple:
#
# - cardstate is NEW, or
# - cardstate is SEEN and its due date for review is today

# %% [markdown]
# # Update the weights (for weighted random selection) for due cards

# %%
# Update 'weight' column for records where 'cardstate' equals 'NEW'
df.loc[df['cardstate'] == 'NEW', 'weight'] = 1

# %%
# Today's date in the same format as the `duedate_calendar` column
today = datetime.now().strftime("%Y-%m-%d")

# Update 'weight' for the specified condition
df.loc[
    (df['cardstate'] == 'SEEN') & (df['duedate_calendar'] == today),
    'weight'
] = 10 / df['interval']

# %%
df.head(30)
# Out:
#     id                                             native  \
# 0    1  The reason for which I couldn't attend the mee...
# 1    2   A few minutes ago, I received an important call.
# 2    3         A new problem has appeared in the project.
# 3    4  After finishing the exams, I decided to unleas...
# 4    5     After he goes to another office, we will meet.
# 5    6  After overcoming his fears, he no longer cared...
# 6    7       After playing, the son's mom will clean Max.
# 7    8  After so many issues, I want to get rid of thi...
# 8    9    After so much practice, I know it by heart now.
# 9   10  After the explanation, it's clear to me that w...
# 10  11        After the sale, only a few units were left.
# 11  12  After trying it several times, he realized it ...
# 12  13  All the students sang in unison during the sch...
# 13  14  Already in the early morning, we decided to go...
# 14  15  Although in the background, his contribution w...
# 15  16  Although we were already tired, we decided to ...
# 16  17  Apparently, he won't make it to the meeting on...
# 17  18  Are you going to quit? No way, I'm not even co...
# 18  19  As an artist, it's important to make oneself k...
# 19  20       As far as I know, the project is going well.
# 20  21       As for the project, there are some concerns.
# 21  22  As I was saying before, the situation is compl...
# 22  23  As part of my routine, I wake up at six every ...
# 23  24  As the day progressed, the heat became more in...
# 24  25  As the holidays approached, excitement grew in...
# 25  26  At first, he didn't take the challenge seriously.
# 26  27  At the conference, they also talked about adva...
# 27  28  At the party, there were no shortage of fun mo...
# 28  29  Before answering, he thinks about it for a min...
# 29  30    Before going out, make sure to apply sunscreen.
#
#                                                target          lastStudied  \
# 0   La razón por la cual no pude asistir a la reun...  09/25/2024 01:00:00
# 1   Hace unos minutos, recibí una llamada importante.  09/25/2024 01:00:00
# 2      Ha aparecido un nuevo problema en el proyecto.  09/25/2024 01:00:00
# 3   Después de terminar los exámenes, decidí dar r...  09/25/2024 01:00:00
# 4   Después de que vaya a otra oficina, nos reunir...  09/25/2024 01:00:00
# 5   Después de superar sus miedos, ya no le import...  09/25/2024 01:00:00
# 6   Después de jugar, la mamá del hijo limpiará a ...  09/25/2024 01:00:00
# 7   Después de tantos problemas, quiero quitarme y...  09/25/2024 01:00:00
# 8   Después de tanto practicar, ahora lo sé de mem...  09/25/2024 01:00:00
# 9   Después de la explicación, me queda claro que ...  09/25/2024 01:00:00
# 10  Después de la venta, solo quedaban algunas uni...  09/25/2024 01:00:00
# 11  Luego de intentarlo varias veces, se dio cuent...  09/25/2024 01:00:00
# 12  Todos los estudiantes cantaron al unísono dura...  09/25/2024 01:00:00
# 13           Ya de madrugada, decidimos irnos a casa.  09/25/2024 01:00:00
# 14  Aunque estaba en segundo plano, su contribució...  09/25/2024 01:00:00
# 15  Aunque ya estábamos cansados, decidimos camina...  09/25/2024 01:00:00
# 16   Al parecer, no llegará a tiempo para la reunión.  09/25/2024 01:00:00
# 17  ¿Vas a renunciar? ¡Qué va, ni siquiera lo esto...  09/25/2024 01:00:00
# 18  Como artista, es importante darse a conocer en...  09/25/2024 01:00:00
# 19               Hasta donde sé, el proyecto va bien.  09/25/2024 01:00:00
# 20  En cuanto al proyecto, hay algunas preocupacio...  09/25/2024 01:00:00
# 21  Como te comentaba antes, la situación es compl...  09/25/2024 01:00:00
# 22  Como parte de mi rutina, me levanto a las seis...  09/25/2024 01:00:00
# 23  Conforme avanzaba el día, el calor se volvía m...  09/25/2024 01:00:00
# 24  Conforme se acercaban las vacaciones, la emoci...  09/25/2024 01:00:00
# 25  Al principio, no se había tomado en serio el d...  09/25/2024 01:00:00
# 26  En la conferencia, se hablaba también de los a...  09/25/2024 01:00:00
# 27  En la fiesta, no faltaron los momentos diverti...  09/25/2024 01:00:00
# 28  Antes de responder, él lo piensa durante un mi...  09/25/2024 01:00:00
# 29  Antes de salir, asegúrate de aplicar bloqueado...  09/25/2024 01:00:00
#
#     interval cardstate            lastdate        due_datetime  \
# 0          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 1          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 2          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 3          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 4          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 5          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 6          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 7          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 8          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 9          5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 10         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 11         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 12         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 13         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 14         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 15         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 16         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 17         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 18         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 19         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
# 20         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 21         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 22         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 23         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 24         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 25         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 26         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 27         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 28         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
# 29         5    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00
#
#    lastdate_calendar duedate_calendar  weight
# 0         2024-09-25       2024-09-25       1
# 1         2024-09-25       2024-09-25       1
# 2         2024-09-25       2024-09-25       1
# 3         2024-09-25       2024-09-25       1
# 4         2024-09-25       2024-09-25       1
# 5         2024-09-25       2024-09-25       1
# 6         2024-09-25       2024-09-25       1
# 7         2024-09-25       2024-09-25       1
# 8         2024-09-25       2024-09-25       1
# 9         2024-09-25       2024-09-25       1
# 10        2024-09-25       2024-09-25       1
# 11        2024-09-25       2024-09-25       1
# 12        2024-09-25       2024-09-25       1
# 13        2024-09-25       2024-09-25       1
# 14        2024-09-25       2024-09-25       1
# 15        2024-09-25       2024-09-25       1
# 16        2024-09-25       2024-09-25       1
# 17        2024-09-25       2024-09-25       1
# 18        2024-09-25       2024-09-25       1
# 19        2024-09-25       2024-09-25       1
# 20        2024-09-25       2024-09-25       0
# 21        2024-09-25       2024-09-25       0
# 22        2024-09-25       2024-09-25       0
# 23        2024-09-25       2024-09-25       0
# 24        2024-09-25       2024-09-25       0
# 25        2024-09-25       2024-09-25       0
# 26        2024-09-25       2024-09-25       0
# 27        2024-09-25       2024-09-25       0
# 28        2024-09-25       2024-09-25       0
# 29        2024-09-25       2024-09-25       0

# %% [markdown]
# # Draw a random (weighted) card
#
# You can loop from here down, drawing new cards and rating them

# %%
# Today's date
today = datetime.now().strftime("%Y-%m-%d")

# Filter the records that are due today
due_today = df[
    (df['cardstate'] == 'NEW') | 
    ((df['cardstate'] == 'SEEN') & (df['duedate_calendar'] == today))
]

# Select one record weighted by the 'weight' column
if not due_today.empty:
    selected_record = due_today.sample(weights=due_today['weight'], n=1)
    # print(selected_record)
else:
    print("No records are due today.")

# %%
selected_record
# Out:
#    id                                             native  \
# 5   6  After overcoming his fears, he no longer cared...
#
#                                               target          lastStudied  \
# 5  Después de superar sus miedos, ya no le import...  09/25/2024 01:00:00
#
#    interval cardstate            lastdate        due_datetime  \
# 5         5       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00
#
#   lastdate_calendar duedate_calendar  weight
# 5        2024-09-25       2024-09-25       1

# %% [markdown]
# # Simulate displaying this flashcard to user

# %%
print(selected_record['native'])
# Out:
# 5    After overcoming his fears, he no longer cared...
# Name: native, dtype: object

# %% [markdown]
# # Get user's response after flipping the card
#
# ## Choices:
# 1. Got it Wrong
# 2. Hard
# 3. Correct
# 4. Easy

# %%
#enter the number for the 
userCardRating = 4

# %%
#debugging
print(selected_record['lastStudied'])
# Out:
# 5    09/25/2024 01:00:00
# Name: lastStudied, dtype: object

# %% [markdown]
# # Update card based on user's rating and save update in dataframe

# %%
index = selected_record.index[0]  # Get the index of the selected record

match userCardRating:
    case 1:
        #reset interval if user got the card wrong
        df.loc[index, 'interval'] = 5
    case 2:
        #set interval if user rated the card HARD
        df.loc[index, 'interval'] *= 1.2
    case 3:
        #set interval if user rated the card CORRECT
        df.loc[index, 'interval'] *= 1.8
    case 4:
        #set interval if user rated the card CORRECT
        df.loc[index, 'interval'] *= 2.5


df.loc[index, 'cardstate'] = 'SEEN'
#set its last studied time to now
df.loc[index, 'lastStudied'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %%
# Convert the 'datetime_text' column to datetime type
df['lastdate'] = pd.to_datetime(df['lastStudied'], format='mixed')
# Add a new column that adds the 'minutes' to the 'datetime' column
df['due_datetime'] = df['lastdate'] + pd.to_timedelta(df['interval'], unit='m')
df['lastdate_calendar'] = df['lastdate'].dt.date
df['duedate_calendar'] = df['due_datetime'].dt.date

# %%
#debugging
print(df.loc[index, 'lastStudied'])
# Out:
# 2024-12-04 13:33:03

# %%
df.head(30)
# Out:
#     id                                             native  \
# 0    1  The reason for which I couldn't attend the mee...
# 1    2   A few minutes ago, I received an important call.
# 2    3         A new problem has appeared in the project.
# 3    4  After finishing the exams, I decided to unleas...
# 4    5     After he goes to another office, we will meet.
# 5    6  After overcoming his fears, he no longer cared...
# 6    7       After playing, the son's mom will clean Max.
# 7    8  After so many issues, I want to get rid of thi...
# 8    9    After so much practice, I know it by heart now.
# 9   10  After the explanation, it's clear to me that w...
# 10  11        After the sale, only a few units were left.
# 11  12  After trying it several times, he realized it ...
# 12  13  All the students sang in unison during the sch...
# 13  14  Already in the early morning, we decided to go...
# 14  15  Although in the background, his contribution w...
# 15  16  Although we were already tired, we decided to ...
# 16  17  Apparently, he won't make it to the meeting on...
# 17  18  Are you going to quit? No way, I'm not even co...
# 18  19  As an artist, it's important to make oneself k...
# 19  20       As far as I know, the project is going well.
# 20  21       As for the project, there are some concerns.
# 21  22  As I was saying before, the situation is compl...
# 22  23  As part of my routine, I wake up at six every ...
# 23  24  As the day progressed, the heat became more in...
# 24  25  As the holidays approached, excitement grew in...
# 25  26  At first, he didn't take the challenge seriously.
# 26  27  At the conference, they also talked about adva...
# 27  28  At the party, there were no shortage of fun mo...
# 28  29  Before answering, he thinks about it for a min...
# 29  30    Before going out, make sure to apply sunscreen.
#
#                                                target          lastStudied  \
# 0   La razón por la cual no pude asistir a la reun...  09/25/2024 01:00:00
# 1   Hace unos minutos, recibí una llamada importante.  09/25/2024 01:00:00
# 2      Ha aparecido un nuevo problema en el proyecto.  09/25/2024 01:00:00
# 3   Después de terminar los exámenes, decidí dar r...  09/25/2024 01:00:00
# 4   Después de que vaya a otra oficina, nos reunir...  09/25/2024 01:00:00
# 5   Después de superar sus miedos, ya no le import...  2024-12-04 13:33:03
# 6   Después de jugar, la mamá del hijo limpiará a ...  09/25/2024 01:00:00
# 7   Después de tantos problemas, quiero quitarme y...  09/25/2024 01:00:00
# 8   Después de tanto practicar, ahora lo sé de mem...  09/25/2024 01:00:00
# 9   Después de la explicación, me queda claro que ...  09/25/2024 01:00:00
# 10  Después de la venta, solo quedaban algunas uni...  09/25/2024 01:00:00
# 11  Luego de intentarlo varias veces, se dio cuent...  09/25/2024 01:00:00
# 12  Todos los estudiantes cantaron al unísono dura...  09/25/2024 01:00:00
# 13           Ya de madrugada, decidimos irnos a casa.  09/25/2024 01:00:00
# 14  Aunque estaba en segundo plano, su contribució...  09/25/2024 01:00:00
# 15  Aunque ya estábamos cansados, decidimos camina...  09/25/2024 01:00:00
# 16   Al parecer, no llegará a tiempo para la reunión.  09/25/2024 01:00:00
# 17  ¿Vas a renunciar? ¡Qué va, ni siquiera lo esto...  09/25/2024 01:00:00
# 18  Como artista, es importante darse a conocer en...  09/25/2024 01:00:00
# 19               Hasta donde sé, el proyecto va bien.  09/25/2024 01:00:00
# 20  En cuanto al proyecto, hay algunas preocupacio...  09/25/2024 01:00:00
# 21  Como te comentaba antes, la situación es compl...  09/25/2024 01:00:00
# 22  Como parte de mi rutina, me levanto a las seis...  09/25/2024 01:00:00
# 23  Conforme avanzaba el día, el calor se volvía m...  09/25/2024 01:00:00
# 24  Conforme se acercaban las vacaciones, la emoci...  09/25/2024 01:00:00
# 25  Al principio, no se había tomado en serio el d...  09/25/2024 01:00:00
# 26  En la conferencia, se hablaba también de los a...  09/25/2024 01:00:00
# 27  En la fiesta, no faltaron los momentos diverti...  09/25/2024 01:00:00
# 28  Antes de responder, él lo piensa durante un mi...  09/25/2024 01:00:00
# 29  Antes de salir, asegúrate de aplicar bloqueado...  09/25/2024 01:00:00
#
#        interval cardstate            lastdate               due_datetime  \
# 0      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 1      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 2      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 3      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 4      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 5   1220.703125      SEEN 2024-12-04 13:33:03 2024-12-05 09:53:45.187500
# 6      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 7      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 8      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 9      5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 10     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 11     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 12     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 13     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 14     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 15     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 16     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 17     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 18     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 19     5.000000       NEW 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 20     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 21     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 22     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 23     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 24     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 25     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 26     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 27     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 28     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
# 29     5.000000    UNSEEN 2024-09-25 01:00:00 2024-09-25 01:05:00.000000
#
#    lastdate_calendar duedate_calendar  weight cardstatus
# 0         2024-09-25       2024-09-25       1        NaN
# 1         2024-09-25       2024-09-25       1        NaN
# 2         2024-09-25       2024-09-25       1        NaN
# 3         2024-09-25       2024-09-25       1        NaN
# 4         2024-09-25       2024-09-25       1        NaN
# 5         2024-12-04       2024-12-05       1       SEEN
# 6         2024-09-25       2024-09-25       1        NaN
# 7         2024-09-25       2024-09-25       1        NaN
# 8         2024-09-25       2024-09-25       1        NaN
# 9         2024-09-25       2024-09-25       1        NaN
# 10        2024-09-25       2024-09-25       1        NaN
# 11        2024-09-25       2024-09-25       1        NaN
# 12        2024-09-25       2024-09-25       1        NaN
# 13        2024-09-25       2024-09-25       1        NaN
# 14        2024-09-25       2024-09-25       1        NaN
# 15        2024-09-25       2024-09-25       1        NaN
# 16        2024-09-25       2024-09-25       1        NaN
# 17        2024-09-25       2024-09-25       1        NaN
# 18        2024-09-25       2024-09-25       1        NaN
# 19        2024-09-25       2024-09-25       1        NaN
# 20        2024-09-25       2024-09-25       0        NaN
# 21        2024-09-25       2024-09-25       0        NaN
# 22        2024-09-25       2024-09-25       0        NaN
# 23        2024-09-25       2024-09-25       0        NaN
# 24        2024-09-25       2024-09-25       0        NaN
# 25        2024-09-25       2024-09-25       0        NaN
# 26        2024-09-25       2024-09-25       0        NaN
# 27        2024-09-25       2024-09-25       0        NaN
# 28        2024-09-25       2024-09-25       0        NaN
# 29        2024-09-25       2024-09-25       0        NaN

# %%
# Close the connection to the database
conn.close()
